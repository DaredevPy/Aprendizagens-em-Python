# %%
# Importar as bibliotecas necessárias

import pyautogui
import time

pyautogui.PAUSE = 0.5
# abrir o navegador
pyautogui.press("win")
pyautogui.write("opera")
time.sleep(2)
pyautogui.press("enter")
time.sleep(5)
# entrar no link 
pyautogui.write("https://music.youtube.com/channel/UCPaaDARDkiWYS5xgadkPg8A")
pyautogui.press("enter")
time.sleep(7)

time.sleep(5)
pyautogui.click(x=447, y=424)
