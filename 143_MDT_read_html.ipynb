# %% [markdown]
# # Metodo read_html

# %%
import pandas as pd
import numpy as np

# %%
# pip install lxml para fazer leitura de arquivos HTML
url = "https://www.mat.ufmg.br/futebol/campeao_seriea/"

tabelas = pd.read_html(url)

df = tabelas[0]

df.sort_values(by="Prob(%)", ascending=True)
# Out:
#      N          Times  Prob(%)
# 19  20          SPORT    0.004
# 18  19      JUVENTUDE    0.049
# 17  18      FORTALEZA    0.052
# 16  17  INTERNACIONAL    0.087
# 15  16        VITÓRIA    0.096
# 14  15      SÃO PAULO    0.140
# 13  14         SANTOS    0.160
# 12  13  VASCO DA GAMA    0.340
# 11  12         GRÊMIO    0.950
# 10  11    CORINTHIANS    1.200
# 9   10          CEARÁ    1.300
# 8    9       MIRASSOL    3.300
# 7    8       BOTAFOGO    3.700
# 6    7       ATLÉTICO    5.400
# 5    6     FLUMINENSE    7.900
# 4    5          BAHIA    8.900
# 3    4     BRAGANTINO   10.800
# 2    3      PALMEIRAS   16.200
# 1    2       CRUZEIRO   16.500
# 0    1       FLAMENGO   22.900
